# %%
# %matplotlib widget

import matplotlib.pyplot as plt
import sys

from TASsello import Material, plot_properties, f1f2Sim

# %%
Cu = Material('ICSD_CollCode136042_Cu.cif')
Cu_properties_ds = Cu.set_properties('ext')
plot_properties(Cu_properties_ds)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
Cu_properties_large_grid_ds = Cu.set_properties('large')
plot_properties(Cu_properties_large_grid_ds)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
sim = f1f2Sim()
sim.set_sim_params(1e-9, 30)
f1, f2 = sim.get_f1_f2()

# %%
plt.figure()
plt.plot(sim.egrid, f1)
plt.plot(sim.egrid, f2)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
